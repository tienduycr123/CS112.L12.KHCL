# %% [markdown]
# **ĐỔI MỚI**
#
# ---
#
# Thành phố quyết định chặt hạ hết **n** cây xanh hiện có trong thành phố để trồng chỉ một loại cây mới. Nhiệm vụ được giao cho Công ty Cây xanh thành phố. Do hạn chế về thiết bị Công ty chỉ tổ chức được 2 đội đốn hạ cây. Đội I hạ được **a** cây mỗi ngày, nhưng cứ mối ngày thứ **k** thì phải nghỉ để bảo dưỡng kỹ thuật, tức là đội I sẽ nghỉ vào các ngày **k**, 2**k**, 3**k**, . . . Đội II hạ được b cây mỗi ngày, nhưng cứ mỗi ngày thứ **m** thì phải nghỉ để bảo dưỡng kỹ thuật, tức là đội II sẽ nghỉ vào các ngày **m**, 2**m**, 3**m**, . . . Ở ngày nghỉ, số cây chặt hạ của đội sẽ là 0. Cả hai đội bắt đầu công việc vào cùng một ngày và làm việc song song với nhau.
#
# Công việc trồng cây mới sẽ bắt đầu sau khi toàn bộ cây cũ đã bị đốn hạ.
#
# Hãy xác định sau bao nhiêu ngày thì có thể bắt đầu việc trồng mới cây.
#
# **Dữ liệu:** Vào từ thiết bị nhập chuẩn gồm một dòng chứa 5 số nguyên **a, k, b, m** và **n** (1 ≤ **a, b** ≤ 10^9, 2 ≤ **k, m** ≤ 10^18, 1 ≤ **n** ≤ 10^18).
#
# **Kết quả:** Đưa ra thiết bị xuất chuẩn một số nguyên – số ngày tính được.

# %% [markdown]
# ## **Abstract**
#
# ---
#
#
# > Given **a, k, b, m** and **n**, find the smallest value of **z** satisfies the condition:
# >> **(z-(z//k)) * a + (z-(z//m)) * b >= n**

# %% [markdown]
# ## **Pattern recognization**
#
#
# ---
#
#
# > Devide and Conquer

# %% [markdown]
# ## **Algorithm designed**
#
#
# ---
#
#
# Input:
# > **a, k, b, m** and **n** are integer (1 ≤ **a, b** ≤ 10^9, 2 ≤ **k, m** ≤ 10^18, 1 ≤ **n** ≤ 10^18)
#
#
# Output:
# > **z**: solution of the equation
#
# Initialize:
# ```
# #Initializes 2 variables "start-bd" and "end-kt" to execute binary search
# bd= 0
# kt= int(1e18)
# #Intializes variable day to save result after binary search
# day= -1
# ```
# Make a def that return the results of an equation (z-(z//k)) * a + (z-(z//m)) * b corresponding to each argument:
# ```
# return ((z-(z//k))*a+(z-(z//m))*b)
# ```
#
# Make a Def: Using Binary Search, loop till the answer is found:
# ```
#     tb= (bd + kt) //2
#     if Sum(tb)>= n:
#         day= tb
#         kt= tb - 1
#     else:
#         bd= tb + 1
# ```
#
# Print:
#
# ```
# day
# ```
# End.

# %% [markdown]
# **Time Complexity : O(*log(n)*)**

# %% [markdown]
# ## **CODE**
#
# ---

# %%
a, k, b, m,n = map(int, input().split())
bd= 0
kt= int(1e18)
day= -1
def Sum(z):
    return ((z-(z//k))*a+(z-(z//m))*b)
while bd<= kt:
    tb= (bd + kt) //2
    if Sum(tb)>= n:  
        day= tb
        kt= tb - 1
    else:           
        bd= tb + 1
print(int(day))
# Out:
# 2 4 3 3 25
# 7
